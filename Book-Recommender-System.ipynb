# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('books.txt')

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0   34889  Brown's Star Atlas: Showing All The Bright Sta...
# 1   22128                     Patriots (The Coming Collapse)
# 2   16914                  The Tolkien Fan's Medieval Reader
# 3   12224  Streetcar Suburbs: The Process of Growth in Bo...
# 4    2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
#
#                                     authors  \
# 0                                     Brown
# 1                              James Wesley
# 2  David E. Smith (Turgon of TheOneRing.net
# 3                           Sam Bass Warner
# 4       Aristophanes/F.W. Hall/W.M. Geldart
#
#                                       average_rating       isbn      isbn13  \
# 0                                     Son & Ferguson          0   851742718
# 1                                             Rawles       3.63  156384155X
# 2   one of the founding members of this Tolkien w...       3.58  1593600119
# 3                                  Jr./Sam B. Warner       3.58   674842111
# 4                                                  5  198145047    9.78E+12
#
#   language_code num_pages  ratings_count  text_reviews_count publication_date  \
# 0      9.78E+12       eng             49                   0                0
# 1      9.78E+12       eng            342                  38                4
# 2      9.78E+12       eng            400                  26                4
# 3      9.78E+12     en-US            236                  61                6
# 4           grc       364              0                   0        2/22/1922
#
#                       publisher                  Unnamed: 12
# 0                    05-01-1977    Brown Son & Ferguson Ltd.
# 1                     1/15/1999  Huntington House Publishers
# 2                    04-06-2004            Cold Spring Press
# 3                     4/20/2004     Harvard University Press
# 4  Oxford University Press  USA                          NaN

# %%
df= df.drop(['Unnamed: 12'],axis=1)

# %%
df.head(10)
# Out:
#    bookID                                              title  \
# 0   34889  Brown's Star Atlas: Showing All The Bright Sta...
# 1   22128                     Patriots (The Coming Collapse)
# 2   16914                  The Tolkien Fan's Medieval Reader
# 3   12224  Streetcar Suburbs: The Process of Growth in Bo...
# 4    2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 5    2560                  Willem de Kooning: Late Paintings
# 6    2843  Literature Circle Guide: Bridge to Terabithia:...
# 7    4287  Middlesex Borough (Images of America: New Jersey)
# 8   14741  Zone of the Enders: The 2nd Runner Official St...
# 9   17224  The Diamond Color Meditation: Color Pathway to...
#
#                                     authors  \
# 0                                     Brown
# 1                              James Wesley
# 2  David E. Smith (Turgon of TheOneRing.net
# 3                           Sam Bass Warner
# 4       Aristophanes/F.W. Hall/W.M. Geldart
# 5           Julie Sylvester/David Sylvester
# 6                            Tara MacCarthy
# 7      Middlesex Borough Heritage Committee
# 8                                Tim Bogenn
# 9                             John  Diamond
#
#                                       average_rating        isbn      isbn13  \
# 0                                     Son & Ferguson           0   851742718
# 1                                             Rawles        3.63  156384155X
# 2   one of the founding members of this Tolkien w...        3.58  1593600119
# 3                                  Jr./Sam B. Warner        3.58   674842111
# 4                                                  5   198145047    9.78E+12
# 5                                                  5  382960226X    9.78E+12
# 6                                                  5   439271711    9.78E+12
# 7                                                  5   738511676    9.78E+12
# 8                                                  5   744002354    9.78E+12
# 9                                                  5  1890995525    9.78E+12
#
#   language_code num_pages  ratings_count  text_reviews_count publication_date  \
# 0      9.78E+12       eng             49                   0                0
# 1      9.78E+12       eng            342                  38                4
# 2      9.78E+12       eng            400                  26                4
# 3      9.78E+12     en-US            236                  61                6
# 4           grc       364              0                   0        2/22/1922
# 5           eng        83              1                   0       09-01-2006
# 6           eng        32              4                   1       01-01-2002
# 7           eng       128              2                   0        3/17/2003
# 8           eng       128              2                   0       03-06-2003
# 9           eng        74              5                   3       02-01-2006
#
#                       publisher
# 0                    05-01-1977
# 1                     1/15/1999
# 2                    04-06-2004
# 3                     4/20/2004
# 4  Oxford University Press  USA
# 5                Schirmer Mosel
# 6            Teaching Resources
# 7            Arcadia Publishing
# 8                    BradyGames
# 9         Square One Publishers

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  object
#  6   language_code       11127 non-null  object
#  7   num_pages           11127 non-null  object
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793649e+04          541.864474
# std    13093.358023   1.124794e+05         2576.174610
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           47.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\asus\desktop\deep_learning\env\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from seaborn) (1.6.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\desktop\deep_learning\env\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)

# %%
import seaborn as sns

# %%
df
# Out:
#        bookID                                              title  \
# 0       34889  Brown's Star Atlas: Showing All The Bright Sta...
# 1       22128                     Patriots (The Coming Collapse)
# 2       16914                  The Tolkien Fan's Medieval Reader
# 3       12224  Streetcar Suburbs: The Process of Growth in Bo...
# 4        2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# ...       ...                                                ...
# 11122   37467  Classroom Interactions as Cross-Cultural Encou...
# 11123   41044                                      Day and Night
# 11124   42758  The Fantastic Vampire: Studies in the Children...
# 11125   44705  The Leadership Challenge: Skills for Taking Ch...
# 11126   45259  Anthony Thwaite: In Conversation With Peter Da...
#
#                                                  authors  \
# 0                                                  Brown
# 1                                           James Wesley
# 2               David E. Smith (Turgon of TheOneRing.net
# 3                                        Sam Bass Warner
# 4                    Aristophanes/F.W. Hall/W.M. Geldart
# ...                                                  ...
# 11122                    Jasmine C.M. Luk/Angel M.Y. Lin
# 11123                           Better Homes and Gardens
# 11124                                  James Craig Holte
# 11125                                   Warren G. Bennis
# 11126  Peter  Dale/Ian          Hamilton/Anthony Thwaite
#
#                                           average_rating        isbn  \
# 0                                         Son & Ferguson           0
# 1                                                 Rawles        3.63
# 2       one of the founding members of this Tolkien w...        3.58
# 3                                      Jr./Sam B. Warner        3.58
# 4                                                      5   198145047
# ...                                                  ...         ...
# 11122                                                  0   805850848
# 11123                                                  0   696018829
# 11124                                                  0   313309337
# 11125                                                  0  088684049X
# 11126                                                  0   953284123
#
#            isbn13 language_code num_pages  ratings_count  text_reviews_count  \
# 0       851742718      9.78E+12       eng             49                   0
# 1      156384155X      9.78E+12       eng            342                  38
# 2      1593600119      9.78E+12       eng            400                  26
# 3       674842111      9.78E+12     en-US            236                  61
# 4        9.78E+12           grc       364              0                   0
# ...           ...           ...       ...            ...                 ...
# 11122    9.78E+12           eng       241              0                   0
# 11123    9.78E+12           eng        32              0                   1
# 11124    9.78E+12           eng       176              0                   0
# 11125    9.78E+12           eng        60              0                   0
# 11126    9.78E+12           eng        96              0                   0
#
#       publication_date                        publisher
# 0                    0                       05-01-1977
# 1                    4                        1/15/1999
# 2                    4                       04-06-2004
# 3                    6                        4/20/2004
# 4            2/22/1922     Oxford University Press  USA
# ...                ...                              ...
# 11122       08-05-2006                        Routledge
# 11123       03-01-1989             Meredith Corporation
# 11124        3/30/2002                  Greenwood Press
# 11125       12-01-1985  AMR/Advanced Management Reports
# 11126       12-09-1999    Between the Lines Productions
#
# [11127 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
top_ten=df[df['ratings_count']>1000000]
top_ten=top_ten.sort_values(by='ratings_count', ascending=False).head(10)
top_ten_rating=top_ten.sort_values(by='average_rating', ascending=False)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,20))
sns.barplot(x="ratings_count", y="title", data=top_ten, palette='inferno')
# Out:
# <AxesSubplot:xlabel='ratings_count', ylabel='title'>

# %%
# %matplotlib inline

# %%
book_auth = df.groupby('authors')['title'].count().reset_index().sort_values('title', ascending=False).head(10).set_index('authors')
book_auth
# Out:
#                              title
# authors
# P.G. Wodehouse                  40
# Stephen King                    40
# Rumiko Takahashi                39
# Orson Scott Card                35
# Agatha Christie                 33
# Piers Anthony                   30
# Mercedes Lackey                 29
# Sandra Brown                    29
# Dick Francis                    28
# Margaret Weis/Tracy Hickman     23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  object
#  6   language_code       11127 non-null  object
#  7   num_pages           11127 non-null  object
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.0+ MB

# %%
df = df.drop(['level_0','index'],axis=1)

# %%
df
# Out:
#        bookID                                              title  \
# 0       34889  Brown's Star Atlas: Showing All The Bright Sta...
# 1       22128                     Patriots (The Coming Collapse)
# 2       16914                  The Tolkien Fan's Medieval Reader
# 3       12224  Streetcar Suburbs: The Process of Growth in Bo...
# 4       11511                                 L'Échiquier du mal
# ...       ...                                                ...
# 11122   22160                           And Then There Were None
# 11123   16313                                A Caribbean Mystery
# 11124   23582  You're Good Enough  You're Smart Enough  & Dog...
# 11125     955  The 5 Love Languages / The 5 Love Languages Jo...
# 11126   40343                          The Full Box (Full  #1-4)
#
#                                         authors  \
# 0                                         Brown
# 1                                  James Wesley
# 2      David E. Smith (Turgon of TheOneRing.net
# 3                               Sam Bass Warner
# 4                                   Dan Simmons
# ...                                         ...
# 11122               Agatha Christie/Hugh Fraser
# 11123            Agatha Christie/Rosalind Ayres
# 11124                                Al Franken
# 11125                              Gary Chapman
# 11126          Janet Evanovich/Charlotte Hughes
#
#                                           average_rating        isbn  \
# 0                                         Son & Ferguson           0
# 1                                                 Rawles        3.63
# 2       one of the founding members of this Tolkien w...        3.58
# 3                                      Jr./Sam B. Warner        3.58
# 4                                                    3.9  2207254410
# ...                                                  ...         ...
# 11122                                               4.26  1572704497
# 11123                                                3.8  1572705493
# 11124                                               3.89   553470949
# 11125                                                4.7   802415318
# 11126                                               4.29  1593979266
#
#            isbn13 language_code num_pages  ratings_count  text_reviews_count  \
# 0       851742718      9.78E+12       eng             49                   0
# 1      156384155X      9.78E+12       eng            342                  38
# 2      1593600119      9.78E+12       eng            400                  26
# 3       674842111      9.78E+12     en-US            236                  61
# 4        9.78E+12           fre       999             63                   7
# ...           ...           ...       ...            ...                 ...
# 11122    9.78E+12           eng         0            214                  49
# 11123    9.78E+12           eng         0             49                  10
# 11124    9.78E+12         en-US         0             18                   0
# 11125    9.78E+12           eng         0             22                   4
# 11126    9.78E+12           eng         0            101                   3
#
#       publication_date                            publisher
# 0                    0                           05-01-1977
# 1                    4                            1/15/1999
# 2                    4                           04-06-2004
# 3                    6                            4/20/2004
# 4           06-08-2003                               Denoël
# ...                ...                                  ...
# 11122       10/15/2004                              Audiogo
# 11123       10-09-2006                              Audiogo
# 11124       10-01-1992  Random House Audio Publishing Group
# 11125       01-01-2005                     Moody Publishers
# 11126        2/16/2016                      Macmillan Audio
#
# [11127 rows x 12 columns]

# %%
df = df.sort_values('num_pages', ascending=False).reset_index()
df = df.iloc[4:]
df.head(20)
# Out:
#     index  bookID                                              title  \
# 4       4   11511                                 L'Échiquier du mal
# 5       5   27847         Data Structures and Abstractions with Java
# 6       6   28898  Fundamentals of Heat and Mass Transfer [with I...
# 7       7   16619                               Democracy in America
# 8       8   11525                 1 000 Places to See Before You Die
# 9       9   28389                              Marcel Proust: A Life
# 10     10   19809  The Last Lion: Winston Spencer Churchill: Visi...
# 11     11   19808  The Last Lion: Winston Spencer Churchill: Visi...
# 12     12   19670                      Debt of Honor (Jack Ryan  #7)
# 13     13   24978                                         Inside Job
# 14     14   31580                                In Search of Duende
# 15     15   44921                                 Explode the Code 1
# 16     16   34307                                      Aches & Pains
# 17     17    7015                          A Midsummer Night's Dream
# 18     18   35539                         The Beatles: The Biography
# 19     21   43236                                     MySQL Cookbook
# 20     22   31871                    History of Political Philosophy
# 21     20   10965         A Breath of Snow and Ashes (Outlander  #6)
# 22     19   14812        The Sword of Angels (The Bronze Knight  #3)
# 23     23   30041                 Elric of Melnibone: Bright Shadows
#
#                                               authors average_rating  \
# 4                                         Dan Simmons            3.9
# 5                  Frank M. Carrano/Walter J. Savitch           3.47
# 6                  Frank P. Incropera/David P. DeWitt           3.99
# 7   Alexis de Tocqueville/Isaac Kramnick/Gerald Bevan           4.02
# 8                                    Patricia Schultz           3.85
# 9                                   William C. Carter           4.33
# 10                                 William Manchester           4.42
# 11                                 William Manchester           4.42
# 12                                         Tom Clancy           4.05
# 13                                      Connie Willis           3.67
# 14    Federico García Lorca/Norman Thomas di Giovanni            4.3
# 15                                         Nancy Hall           4.37
# 16                            Maeve Binchy/Wendy Shea           3.53
# 17                      William Shakespeare/Roma Gill           3.94
# 18                                          Bob Spitz           4.15
# 19                                        Paul DuBois              4
# 20                         Leo Strauss/Joseph Cropsey           4.17
# 21                                     Diana Gabaldon           4.44
# 22                                         John Marco            3.9
# 23        Charles  Green/Richard Ford/Pascal Quidault              4
#
#           isbn    isbn13 language_code num_pages  ratings_count  \
# 4   2207254410  9.78E+12           fre       999             63
# 5   013237045X  9.78E+12           eng       998             34
# 6    470055545  9.78E+12         en-US       997              6
# 7    140447601  9.78E+12           eng       992          18925
# 8    761104844  9.78E+12           eng       992          36303
# 9    300094000  9.78E+12           eng       992             14
# 10   385313489  9.78E+12           eng       992           9659
# 11   316545031  9.78E+12         en-US       992            335
# 12   425147584  9.78E+12           eng       990          39521
# 13  1596060247  9.78E+12           eng        99           1442
# 14   811213765  9.78E+12           eng        99            616
# 15   838814603  9.78E+12           eng        99             89
# 16   385335105  9.78E+12         en-US        99            356
# 17   198320213  9.78E+12           eng        99             14
# 18   316013315  9.78E+12           eng       983           9041
# 19  059652708X  9.78E+12         en-US       980            126
# 20   226777103  9.78E+12           eng       980            441
# 21   385340397  9.78E+12           eng       980         105950
# 22  075640360X  9.78E+12         en-US       980            827
# 23  1905850581  9.78E+12           eng        98              8
#
#     text_reviews_count publication_date                     publisher
# 4                    7       06-08-2003                        Denoël
# 5                    3       08-04-2006                 Prentice Hall
# 6                    0       10/30/2006                         Wiley
# 7                  523        4/24/2003              Penguin Classics
# 8                  439        5/22/2003    Workman Publishing Company
# 9                    4       02-08-2002         Yale University Press
# 10                 467       04-01-1984                         Delta
# 11                  38        5/30/1983       Little  Brown & Company
# 12                 469       08-01-1995                 Berkley Books
# 13                 180       06-01-2005            Subterranean Press
# 14                  36        4/17/1998                New Directions
# 15                  10       01-01-2001   School Specialty Publishing
# 16                  30        6/13/2000               Delacorte Press
# 17                   3        8/15/2002  Oxford University Press  USA
# 18                 417       10-10-2005                  Little Brown
# 19                   8       12-04-2006                O'Reilly Media
# 20                  27       11/30/1987   University of Chicago Press
# 21                3992        8/29/2006                         Delta
# 22                  23       07-01-2006                     Daw Books
# 23                   0       04-01-2008           Mongoose Publishing

# %%
df.num_pages = df.num_pages.astype(float)
df.average_rating = df.average_rating.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 4 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               11123 non-null  int64
#  1   bookID              11123 non-null  int64
#  2   title               11123 non-null  object
#  3   authors             11123 non-null  object
#  4   average_rating      11123 non-null  float64
#  5   isbn                11123 non-null  object
#  6   isbn13              11123 non-null  object
#  7   language_code       11123 non-null  object
#  8   num_pages           11123 non-null  float64
#  9   ratings_count       11123 non-null  int64
#  10  text_reviews_count  11123 non-null  int64
#  11  publication_date    11123 non-null  object
#  12  publisher           11123 non-null  object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize=(20,20))
ax=sns.relplot( x="average_rating", y="num_pages",data=df,sizes=(400,200), height=7)
plt.title('Relation between Rating counts and no pages')
ax.set_axis_labels("average_rating", "no pages")

# %% [markdown]
# ## Data Prep

# %%
df2 = df.copy()

# %%
df2.loc[(df2['average_rating']>=0)&(df2['average_rating']<=1),'rating between']="between 0 and 1"
df2.loc[(df2['average_rating']>1)&(df2['average_rating']<=2),'rating between']="between 1 and 2"
df2.loc[(df2['average_rating']>2)&(df2['average_rating']<=3),'rating between']="between 2 and 3"
df2.loc[(df2['average_rating']>3)&(df2['average_rating']<=4),'rating between']="between 3 and 4"
df2.loc[(df2['average_rating']>4)&(df2['average_rating']<=5),'rating between']="between 4 and 5"

# %%
df2.sort_values('average_rating')
# Out:
#        index  bookID                                              title  \
# 10823  10790    1302                     Juiced Official Strategy Guide
# 7635    7627   37467  Classroom Interactions as Cross-Cultural Encou...
# 7491    7506   28467                   Sclerotherapy and vein treatment
# 5032    5108   36946      Random House Crossword Mega Omnibus  Volume 1
# 8837    8864    3351           Open City 6: The Only Woman He Ever Left
# ...      ...     ...                                                ...
# 8881    8891   19786  The Goon Show  Volume 4: My Knees Have Fallen ...
# 133       70   18184  The Complete Theory Fun Factory: Music Theory ...
# 1602    1616   23552                        The New Big Book of America
# 2341    2299   41639         Bill Gates: Computer Legend (Famous Lives)
# 5745    5736   39580  The American Campaign: U.S. Presidential Campa...
#
#                                                  authors  average_rating  \
# 10823                                         Doug Walsh             0.0
# 7635                     Jasmine C.M. Luk/Angel M.Y. Lin             0.0
# 7491   Robert A. Weiss/Margaret A. Weiss/Karen L. Bea...             0.0
# 5032                          United Feature Syndication             0.0
# 8837   Open City Magazine/James Purdy/Daniel Pinchbec...             0.0
# ...                                                  ...             ...
# 8881                                          NOT A BOOK             5.0
# 133                      Ian        Martin/Katie Elliott             5.0
# 1602                                Todd Davis/Marc Frey             5.0
# 2341                                    Sara Barton-Wood             5.0
# 5745                                   James E. Campbell             5.0
#
#              isbn    isbn13 language_code  num_pages  ratings_count  \
# 10823   744005612  9.78E+12           eng      112.0              0
# 7635    805850848  9.78E+12           eng      241.0              0
# 7491     71485422  9.78E+12           eng      248.0              0
# 5032   081292763X  9.78E+12           eng      336.0              0
# 8837   189044717X  9.78E+12           eng      200.0              0
# ...           ...       ...           ...        ...            ...
# 8881    563388692  9.78E+12           eng        2.0              3
# 133     851621813  9.78E+12           eng       96.0              1
# 1602    762412631  9.78E+12           eng       56.0              2
# 2341    739844326  9.78E+12           eng       48.0              0
# 5745   089096940X  9.78E+12           eng      314.0              0
#
#        text_reviews_count publication_date  \
# 10823                   0       06-01-2005
# 7635                    0       08-05-2006
# 7491                    0       12/30/2011
# 5032                    0        7/22/1997
# 8837                    0       10/13/2000
# ...                   ...              ...
# 8881                    0       04-01-1996
# 133                     0       06-01-2004
# 1602                    1        3/21/2002
# 2341                    0       11-01-2001
# 5745                    0       05-01-2000
#
#                                  publisher   rating between
# 10823                           BradyGames  between 0 and 1
# 7635                             Routledge  between 0 and 1
# 7491   McGraw-Hill Professional Publishing  between 0 and 1
# 5032          Random House Puzzles & Games  between 0 and 1
# 8837          Grove Press  Open City Books  between 0 and 1
# ...                                    ...              ...
# 8881                    BBC Physical Audio  between 4 and 5
# 133                    Boosey & Hawkes Inc  between 4 and 5
# 1602                         Courage Books  between 4 and 5
# 2341                              Raintree  between 4 and 5
# 5745            Texas A&M University Press  between 4 and 5
#
# [11123 rows x 14 columns]

# %%
rating_df = pd.get_dummies(df2['rating between'])
language_Df = pd.get_dummies(df2['language_code'])

# %%
feature=pd.concat([rating_df, language_Df, df2['average_rating'], df2['ratings_count']], axis=1)

# %%
feature
# Out:
#        between 0 and 1  between 1 and 2  between 2 and 3  between 3 and 4  \
# 4                    0                0                0                1
# 5                    0                0                0                1
# 6                    0                0                0                1
# 7                    0                0                0                0
# 8                    0                0                0                1
# ...                ...              ...              ...              ...
# 11122                0                0                0                1
# 11123                0                0                0                1
# 11124                0                0                0                1
# 11125                0                0                0                1
# 11126                0                0                0                0
#
#        between 4 and 5  ale  ara  en-CA  en-GB  en-US  ...  por  rus  spa  \
# 4                    0    0    0      0      0      0  ...    0    0    0
# 5                    0    0    0      0      0      0  ...    0    0    0
# 6                    0    0    0      0      0      1  ...    0    0    0
# 7                    1    0    0      0      0      0  ...    0    0    0
# 8                    0    0    0      0      0      0  ...    0    0    0
# ...                ...  ...  ...    ...    ...    ...  ...  ...  ...  ...
# 11122                0    0    0      0      0      0  ...    0    0    0
# 11123                0    0    0      0      0      0  ...    0    0    0
# 11124                0    0    0      0      0      0  ...    0    0    0
# 11125                0    0    0      0      0      0  ...    0    0    0
# 11126                1    0    0      0      0      0  ...    0    0    0
#
#        srp  swe  tur  wel  zho  average_rating  ratings_count
# 4        0    0    0    0    0            3.90             63
# 5        0    0    0    0    0            3.47             34
# 6        0    0    0    0    0            3.99              6
# 7        0    0    0    0    0            4.02          18925
# 8        0    0    0    0    0            3.85          36303
# ...    ...  ...  ...  ...  ...             ...            ...
# 11122    0    0    0    0    0            4.00              7
# 11123    0    0    0    0    0            3.84             91
# 11124    0    0    0    0    0            3.51             42
# 11125    0    0    0    0    0            3.89              2
# 11126    0    0    0    0    0            4.29            101
#
# [11123 rows x 34 columns]

# %% [markdown]
# ## Building Model

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()

feature = minmax.fit_transform(feature)

# %%
feature
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 7.80000000e-01, 1.37026048e-05],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 6.94000000e-01, 7.39505654e-06],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 7.98000000e-01, 1.30500998e-06],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 7.02000000e-01, 9.13506984e-06],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 7.78000000e-01, 4.35003326e-07],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.58000000e-01, 2.19676679e-05]])

# %%
from sklearn import neighbors
from sklearn.model_selection import train_test_split

# %%
model = neighbors.NearestNeighbors(n_neighbors=10, algorithm='auto')
model.fit(feature)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
dist, idlist = model.kneighbors(feature)

# %%
dist
# Out:
# array([[0.00000000e+00, 2.82761068e-06, 3.11027394e-05, ...,
#         4.00001420e-03, 4.00001478e-03, 4.00001921e-03],
#        [0.00000000e+00, 4.34950576e-07, 2.17505916e-06, ...,
#         6.52500734e-06, 2.26201787e-05, 4.08903122e-05],
#        [0.00000000e+00, 8.70156367e-07, 1.52254579e-06, ...,
#         2.97977325e-05, 5.28529000e-05, 1.00485766e-04],
#        ...,
#        [0.00000000e+00, 1.74005754e-06, 2.60995870e-06, ...,
#         2.02276663e-05, 3.19727462e-05, 4.02378150e-05],
#        [0.00000000e+00, 2.17985195e-07, 4.34950576e-07, ...,
#         3.26250367e-06, 5.00257526e-06, 6.96003873e-06],
#        [0.00000000e+00, 1.30485173e-06, 5.22000247e-06, ...,
#         1.39201094e-05, 1.43551015e-05, 1.74001415e-05]])

# %%
df2.head()
# Out:
#    index  bookID                                              title  \
# 4      4   11511                                 L'Échiquier du mal
# 5      5   27847         Data Structures and Abstractions with Java
# 6      6   28898  Fundamentals of Heat and Mass Transfer [with I...
# 7      7   16619                               Democracy in America
# 8      8   11525                 1 000 Places to See Before You Die
#
#                                              authors  average_rating  \
# 4                                        Dan Simmons            3.90
# 5                 Frank M. Carrano/Walter J. Savitch            3.47
# 6                 Frank P. Incropera/David P. DeWitt            3.99
# 7  Alexis de Tocqueville/Isaac Kramnick/Gerald Bevan            4.02
# 8                                   Patricia Schultz            3.85
#
#          isbn    isbn13 language_code  num_pages  ratings_count  \
# 4  2207254410  9.78E+12           fre      999.0             63
# 5  013237045X  9.78E+12           eng      998.0             34
# 6   470055545  9.78E+12         en-US      997.0              6
# 7   140447601  9.78E+12           eng      992.0          18925
# 8   761104844  9.78E+12           eng      992.0          36303
#
#    text_reviews_count publication_date                   publisher  \
# 4                   7       06-08-2003                      Denoël
# 5                   3       08-04-2006               Prentice Hall
# 6                   0       10/30/2006                       Wiley
# 7                 523        4/24/2003            Penguin Classics
# 8                 439        5/22/2003  Workman Publishing Company
#
#     rating between
# 4  between 3 and 4
# 5  between 3 and 4
# 6  between 3 and 4
# 7  between 4 and 5
# 8  between 3 and 4

# %%
def bookRec(name):
    book_list = []
    book_id = df2[df2['title']==name].index
    book_id= book_id[0]
    for new in idlist[book_id]:
        book_list.append(df2.loc[new].title)
    return book_list

Book_name = bookRec("Democracy in America")
Book_name
# Out:
# ['Democracy in America',
#  'You Can Have What You Want: Proven Strategies for Inner and Outer Success',
#  'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year',
#  'Whiteout',
#  'Novels and Stories',
#  "World's End",
#  'Pilgrim at Tinker Creek',
#  'Novels 1956–1964: Seize the Day / Henderson the Rain King / Herzog',
#  'Lives of Girls and Women',
#  "Mission: Where's June? (Disney's Little Einstein)"]
